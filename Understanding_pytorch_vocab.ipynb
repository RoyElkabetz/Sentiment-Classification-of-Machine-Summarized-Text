# %% [markdown]
# <a href="https://colab.research.google.com/github/RoyElkabetz/Text-Summarization-with-Deep-Learning/blob/main/Understanding_pytorch_vocab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import time

import torch
# from torchtext.datasets import IMDB as the_dataset
from torchtext.datasets import AG_NEWS as the_dataset
import torchtext.data as data
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torchtext.data.functional import to_map_style_dataset
from torch.utils.data import DataLoader
from torch.utils.data.dataset import random_split
from torch import nn




print(f'torch {torch.__version__}')
print('Device properties:')
if torch.cuda.is_available():
    device = torch.device("cuda")
    gpu_data = torch.cuda.get_device_properties(0)
    gpu_name = gpu_data.name
    gpu_mem  = f'{gpu_data.total_memory * 1e-9:.02f} Gb'
    print(f'GPU: {gpu_name}\nMemory: {gpu_mem}')
else:
    device = torch.device("cpu")
    print('CPU')
# Out:
# torch 1.9.0+cu102
# Device properties:
# CPU

# %%
tokenizer = get_tokenizer('basic_english')
train_iter = the_dataset(split='train')

def yield_tokens(data_iter):
    for _, text in data_iter:
        yield tokenizer(text)

vocab = build_vocab_from_iterator(yield_tokens(train_iter), specials=["<unk>", "<sos>", "<eos>"])
vocab.set_default_index(vocab["<unk>"])

# %%
# get index of a single word
vocab['yes']
# Out:
# 5166

# %%
# get indices of a list of words
words = ['my', 'name', 'is', 'jdsckdsc']
vocab.forward(words)
# Out:
# [1302, 953, 23, 0]

# %%
# size of vocabulary
print(len(vocab))
# Out:
# 95813

# %%
# setting the out of vocabulary (OOV) index
vocab.set_default_index(99999999)
vocab['wrbcwkcbwkj']
# Out:
# 99999999

# %%
vocab.get_default_index()
# Out:
# 99999999

# %%
# append a token at a specific index
print(vocab['elkabetz'])
vocab.insert_token('elkabetz', 12)
print(vocab['elkabetz'])
# Out:
# 99999999
# 12

# %%
# try to append an excisting token
vocab.append_token('elkabetz')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-35-9bc70691618b> in <module>()
# ----> 1 vocab.append_token('elkabetz')
#
# /usr/local/lib/python3.7/dist-packages/torchtext/vocab.py in append_token(self, token)
#     120             RuntimeError: If `token` already exists in the vocab
#     121         """
# --> 122         self.vocab.append_token(token)
#     123
#     124     @torch.jit.export
#
# RuntimeError: Token elkabetz already exists in the Vocab with index: 12

# %%
# append a nonexcisting token
vocab.append_token('royelkabetz1')
print(vocab['royelkabetz1'])
# Out:
# 95815

# %%
vocab.get_stoi()
# Out:
# {'zzzzzz': 95813,
#  'zzz': 95812,
#  'zygmunt': 95810,
#  'zvezda': 95807,
#  'zurine': 95806,
#  'zurab': 95804,
#  'zuloaga': 95802,
#  'zulf': 95801,
#  'zuhua': 95800,
#  'zseries': 95797,
#  'zotinca': 95794,
#  'zos': 95793,
#  'zopyros': 95790,
#  'zoock': 95787,
#  'zoo\\as': 95786,
#  'zone-h': 95782,
#  'zoll': 95780,
#  'zolecki': 95779,
#  'zocalo': 95775,
#  'zits': 95772,
#  'zirconium': 95770,
#  'zinter': 95768,
#  'zinged': 95767,
#  'zims': 95766,
#  'zimmerman': 95765,
#  'zilch': 95763,
#  'zif': 95758,
#  'zico': 95757,
#  'ziadi': 95756,
#  'zhukov\\said': 95755,
#  'zhirkov': 95754,
#  'zhiguli': 95753,
#  'zesn': 95748,
#  'zero-tolerance': 95746,
#  'zero-profit': 95744,
#  'zero-energy': 95742,
#  'zeppieri': 95740,
#  'zen-like': 95734,
#  'zemaryalai': 95733,
#  'zeitoun': 95731,
#  'zeitgeist': 95730,
#  'zealous': 95729,
#  'zealand-qantas': 95726,
#  'zdenek': 95722,
#  'zd8000': 95721,
#  'zawodny': 95720,
#  'zavos': 95718,
#  'zauchensee': 95717,
#  'zauberfloete': 95716,
#  'zarya': 95714,
#  'zarqawis': 95713,
#  'zapruder': 95711,
#  'zapatistas': 95708,
#  'zane': 95703,
#  'zalpa': 95700,
#  'zaloudek': 95699,
#  'zalmaykhalilzad': 95698,
#  'zakinthos': 95696,
#  'zaire': 95691,
#  'zainabia': 95688,
#  'zahira': 95684,
#  'zagat': 95681,
#  'zafi-b': 95680,
#  'zafarullah': 95679,
#  'zaentz': 95677,
#  'za/view': 95672,
#  'z1': 95670,
#  'z/os': 95668,
#  'yv': 95664,
#  'yusef': 95661,
#  'yuschenkos': 95660,
#  'yunshan': 95659,
#  'yuliana': 95655,
#  'yulia': 95654,
#  'yukiko': 95650,
#  'yudhoyono\\has': 95641,
#  'yuck': 95639,
#  'yucca': 95638,
#  'yuba': 95637,
#  'ysearchblog': 95634,
#  'yrk': 95632,
#  'yoyong': 95630,
#  'youths\\rampaged': 95628,
#  'yourdon': 95623,
#  'your\\old': 95620,
#  'your\\favorite': 95619,
#  'youppi': 95618,
#  'young\\palestinian': 95616,
#  'young\\consumers': 95615,
#  'young-hee': 95613,
#  'young-adult': 95612,
#  'you\\can': 95608,
#  'you\\': 95605,
#  'yoshioka': 95603,
#  'yoshihide': 95598,
#  'yorkwal-mart': 95596,
#  'yorkmartha': 95592,
#  'yorkjust': 95591,
#  'yorkibm': 95590,
#  'yorkhitachi': 95589,
#  'york\\mercantile': 95582,
#  'york/philadelphia': 95579,
#  'york/new': 95578,
#  'york/helsinki': 95575,
#  'york-the': 95573,
#  'york-quoted': 95572,
#  'york-japan': 95571,
#  'york--pharmacy': 95568,
#  'york--ibm': 95566,
#  'york---tenet': 95564,
#  'yoof': 95561,
#  'yongjori': 95558,
#  'yong': 95557,
#  'yippee': 95545,
#  'yiorgos': 95544,
#  'yevgeny': 95539,
#  'yetunde': 95538,
#  'yet-unknown': 95535,
#  'yet--withdraws': 95533,
#  'yester-sol': 95530,
#  'yeserday': 95526,
#  'yerevan': 95524,
#  'yer': 95523,
#  'yep': 95522,
#  'yeomans': 95521,
#  'yeoman': 95520,
#  'yen\\programmer': 95517,
#  'yemens': 95512,
#  'yemenidjian': 95511,
#  'yemeni\\national': 95510,
#  'yemeni\\accused': 95509,
#  'yello': 95504,
#  'yeh': 95503,
#  'yediot': 95502,
#  'yearshuman': 95501,
#  'yearseach': 95500,
#  'years\\with': 95499,
#  'years\\of': 95496,
#  'years\\demonstrated': 95494,
#  'years-old': 95492,
#  'years--how': 95491,
#  'yearns': 95489,
#  'yearlings': 95487,
#  'year\\of': 95483,
#  'year\\market': 95482,
#  'year\\end': 95479,
#  'year\\ago': 95478,
#  'year\\\\us': 95477,
#  'year-to-year': 95476,
#  'year-to-june': 95475,
#  'year-round': 95474,
#  'year-long\\bankruptcy': 95470,
#  'year-ago\\loss': 95465,
#  'year-': 95462,
#  'yeagley': 95461,
#  'ydstie': 95460,
#  'yawned': 95459,
#  'yasuo': 95457,
#  'yassin-style': 95454,
#  'yasini': 95453,
#  'yashwanthpur': 95452,
#  'yashin': 95451,
#  'yasgur': 95450,
#  'yarn': 95448,
#  'yarde': 95445,
#  'yapping': 95443,
#  'yap': 95442,
#  'yanping': 95440,
#  'yankees\\which': 95438,
#  'yankees\\tuesday': 95437,
#  'yankees-twins': 95436,
#  'yankee-red': 95432,
#  'yankee-bashing': 95431,
#  'yamamah': 95426,
#  'yale-new': 95424,
#  'yakking': 95422,
#  'yakin': 95421,
#  'yai': 95418,
#  'yahoo\\\\on': 95415,
#  'xxxv': 95403,
#  'xxxiv': 95402,
#  'xwiki': 95398,
#  'xrx': 95391,
#  'xprize': 95389,
#  'xpm': 95387,
#  'xp\\computer': 95385,
#  'xp-': 95384,
#  'xml/rss': 95381,
#  'xinhua\\news': 95375,
#  'xingsheng': 95374,
#  'xide': 95370,
#  'xgm': 95362,
#  'xforms': 95360,
#  'xeroxinstitution': 95359,
#  'xeroxing': 95358,
#  'xeon-based': 95356,
#  'xd-picture': 95350,
#  'xaml': 95345,
#  'x\\v10': 95341,
#  'x86-based': 95339,
#  'x300': 95336,
#  'x-type': 95334,
#  'x-box': 95329,
#  'x-43-a': 95327,
#  'wynton': 95326,
#  'wylie': 95325,
#  'wwii-themed': 95321,
#  'wvum': 95320,
#  'wvirginia': 95319,
#  'wusa-9': 95316,
#  'wus': 95315,
#  'wurster': 95314,
#  'wuqiang': 95313,
#  'wunsiedel': 95312,
#  'wunderteam': 95311,
#  'wumart': 95309,
#  'wuling': 95308,
#  'wtvj': 95305,
#  'wtnh/ap': 95301,
#  'wtnh': 95300,
#  'wtn': 95299,
#  'wti': 95298,
#  'wtas': 95296,
#  'wss2003': 95294,
#  'wsis': 95293,
#  'wsb': 95292,
#  'ws-architecture': 95290,
#  'wru': 95289,
#  'wrt': 95288,
#  'wrong-footing': 95286,
#  'written\\off': 95284,
#  'wrigley\\field': 95276,
#  'wriggled': 95273,
#  'wrests': 95271,
#  'wrestling-boxing': 95270,
#  'wreathed': 95267,
#  'wrca': 95266,
#  'wrc-1260': 95265,
#  'wrapup-1-glamour': 95260,
#  'wqam': 95258,
#  'wpp\\': 95257,
#  'wpp-grey': 95256,
#  'wpni': 95255,
#  'wpi': 95254,
#  'wounded\\when': 95249,
#  'wounded\\at': 95247,
#  'wounded\\65': 95246,
#  'woulddisrupt': 95244,
#  'would\\you': 95243,
#  'would\\require': 95240,
#  'would\\hold': 95237,
#  'woth': 95231,
#  'woss': 95230,
#  'worthman': 95229,
#  'worth\\checking': 95227,
#  'worth-in': 95225,
#  'worst-performing': 95223,
#  'worst-kept': 95222,
#  'worst-jobs': 95221,
#  'worse-shooting': 95218,
#  'worry\\about': 95217,
#  'worriers': 95215,
#  'worming': 95211,
#  'worm-based': 95207,
#  'worldwide_': 95205,
#  'worldview': 95203,
#  'worldly': 95201,
#  'worldcom-sprint': 95197,
#  'world\\finance': 95192,
#  'world\\chess': 95190,
#  'world\\body': 95188,
#  'world-surprise': 95185,
#  'world-leading': 95181,
#  'world-champion': 95177,
#  'world-beating': 95176,
#  'world-acclaimed': 95175,
#  'workspaces': 95173,
#  'workshare': 95172,
#  'workforce-reduction': 95168,
#  'workdays': 95164,
#  'workaround': 95162,
#  'work\\this': 95161,
#  'work-visa': 95157,
#  'work-sharing': 95156,
#  'woosie': 95146,
#  'wooping': 95145,
#  'wooo': 95144,
#  'woolworths-led': 95141,
#  'woolfolk': 95139,
#  'woodpecker': 95130,
#  'wood-processing': 95127,
#  'wood-paneled': 95126,
#  'wood-panel': 95125,
#  'woo\\customers': 95123,
#  'woo-kim': 95122,
#  'wonderboy': 95115,
#  'won1': 95110,
#  'womenswear': 95108,
#  'women\\relatives': 95107,
#  'women-only': 95106,
#  'womans': 95105,
#  'wolfmeyer': 95101,
#  'woking': 95097,
#  'wohl': 95094,
#  'woebegone': 95093,
#  'wmcs': 95085,
#  'wltpctpfpanew': 95084,
#  'wlll': 95081,
#  'wjib': 95076,
#  'wjda': 95075,
#  'wizardsinsider': 95074,
#  'wits\\against': 95071,
#  'withthe': 95069,
#  'withstanding': 95068,
#  'withraws': 95067,
#  'without\\starter': 95065,
#  'without\\permission': 95063,
#  'within\\three': 95060,
#  'xiaobo': 95368,
#  'withdisloyalty': 95052,
#  'with\\yahoo': 95051,
#  'with\\turkey': 95048,
#  'with\\tropical': 95047,
#  'with\\their': 95046,
#  'with\\state': 95045,
#  'with\\rebels': 95041,
#  'with\\powerful': 95038,
#  'with\\politics': 95037,
#  'with\\oracle': 95033,
#  'with\\last': 95030,
#  'with\\jewel-encrusted': 95029,
#  'with\\industry': 95025,
#  'with\\extinction': 95022,
#  'with\\directv': 95019,
#  'with\\decapitated': 95016,
#  'with\\consumer': 95015,
#  'with\\bogus': 95011,
#  'with\\bases': 95009,
#  'witching': 95001,
#  'witch': 94998,
#  'wisser': 94996,
#  'wishesto': 94992,
#  'wishers': 94991,
#  'wisecracking': 94987,
#  'wisconsin-parkside': 94984,
#  'wisc': 94983,
#  'wiry': 94981,
#  'wirelessconnections': 94978,
#  'wireless\\communications': 94974,
#  'wireless-telecommunications': 94971,
#  'wireless-lan': 94969,
#  'wireless-j': 94968,
#  'wireless-data': 94965,
#  'wireless-at': 94964,
#  'wippit\\has': 94961,
#  'wipc/ifex': 94959,
#  'winter\\blizzard': 94956,
#  'winsome': 94954,
#  'winslet': 94953,
#  'winnowing': 94951,
#  'winnipegger': 94949,
#  'winlessness': 94943,
#  'wining': 94941,
#  'winemaking\\from': 94936,
#  'wine-growing': 94932,
#  'windup': 94931,
#  'windshifts': 94929,
#  'windsailing': 94927,
#  'winds\\of': 94926,
#  'windowsupdate': 94925,
#  'windows\\software': 94923,
#  'windows-run': 94921,
#  'windows-linux': 94918,
#  'windows-like': 94917,
#  'windows-friendly': 94916,
#  'windows-desktop': 94914,
#  'windows-certified': 94913,
#  'windowing': 94911,
#  'window-dressing': 94909,
#  'windless': 94908,
#  'windbreaker': 94906,
#  'windblown': 94905,
#  'wind-powered': 94902,
#  'wind-power': 94901,
#  'wind-fueled': 94900,
#  'win\\new': 94895,
#  'win-': 94891,
#  'wimax-based': 94889,
#  'wilmington-based': 94886,
#  'williams/bmw': 94878,
#  'williams-klitschko': 94877,
#  'yoshihiro': 95599,
#  'willamette': 94872,
#  'will\\use': 94871,
#  'will\\unveil': 94870,
#  'will\\stress': 94867,
#  'will\\offer': 94860,
#  'will\\influence': 94858,
#  'will\\improve': 94857,
#  'will\\focus': 94855,
#  'will\\ask': 94846,
#  'will\\any': 94845,
#  'will&lt': 94840,
#  'wilkerson': 94838,
#  'wiljan': 94837,
#  'yaar': 95408,
#  'wilhelmsson': 94835,
#  'wilfredo': 94833,
#  'wile': 94831,
#  'wildtangent': 94830,
#  'wildlife\\officials': 94826,
#  'wild-card-clinching': 94819,
#  'wilczeck': 94816,
#  'wikidoc': 94815,
#  'wigo': 94812,
#  'wiesbaden': 94807,
#  'widths': 94801,
#  'widowed': 94800,
#  'widnall': 94799,
#  'widespread\\accounting': 94797,
#  'wider-than-anticipated': 94793,
#  'widely-suspected': 94784,
#  'widely-prescribed': 94783,
#  'widely-expected': 94781,
#  'wide-raging': 94779,
#  'wicklund': 94774,
#  'wicket-taking': 94773,
#  'wickedest': 94770,
#  'wich': 94769,
#  'wiapahu': 94767,
#  'wi-fi\\gear': 94766,
#  'why-worry': 94762,
#  'whur': 94761,
#  'whupped': 94760,
#  'whs': 94758,
#  'whrb': 94757,
#  'whovenezuelan': 94755,
#  'whove': 94754,
#  'whose\\departure': 94752,
#  'whopper': 94751,
#  'wholesale\\discounts': 94745,
#  'wholeheartedly': 94743,
#  'whole\\new': 94742,
#  'whole-owned': 94741,
#  'who\\told': 94739,
#  'who\\originated': 94736,
#  'who\\loves': 94732,
#  'who\\has': 94730,
#  'who\\found': 94728,
#  'whizkid': 94723,
#  'whitworth': 94722,
#  'whittier': 94720,
#  'whitley': 94716,
#  'whiteboard': 94710,
#  'white\\house': 94709,
#  'white-walled': 94708,
#  'white-robed': 94707,
#  'white-out': 94705,
#  'white-gloved': 94702,
#  'white-flag': 94701,
#  'white-dominated': 94699,
#  'whitcomb': 94698,
#  'whitacre': 94697,
#  'whispered': 94695,
#  'whipstitching': 94688,
#  'whipsawing': 94686,
#  'whined': 94681,
#  'whim': 94679,
#  'while\\wireless': 94678,
#  'while\\vowing': 94677,
#  'while\\the': 94676,
#  'while\\profit-taking': 94674,
#  'while\\profit': 94673,
#  'while\\investors': 94671,
#  'while\\another': 94667,
#  'while--but': 94664,
#  'whiffs': 94663,
#  'which\\ranks': 94658,
#  'which\\companies': 94646,
#  'whether\\the': 94641,
#  'whether\\a': 94639,
#  'whereresidents': 94637,
#  'where\\wireless': 94634,
#  'where\\more': 94633,
#  'where\\looting': 94632,
#  'where\\it': 94631,
#  'wherabouts': 94628,
#  'when\\you': 94627,
#  'when\\the': 94624,
#  'when\\life': 94622,
#  'when\\its': 94621,
#  'wheelchairs': 94618,
#  'wheatman': 94616,
#  'what\\sources': 94614,
#  'what\\officials': 94613,
#  'what\\mp3': 94612,
#  'what\\may': 94611,
#  'what\\kind': 94610,
#  'what\\investigators': 94608,
#  'what-ifs': 94606,
#  'wharton': 94605,
#  'whale-watch': 94603,
#  'whacked-out': 94599,
#  'wgo': 94597,
#  'wfan': 94594,
#  'weyerhauser': 94592,
#  'wet-weather': 94588,
#  'westwood-based': 94585,
#  'westly': 94581,
#  'westlake': 94580,
#  'westheimer': 94579,
#  'westerns': 94576,
#  'western\\mediators': 94572,
#  'west\\side': 94566,
#  'west\\african': 94564,
#  'wessels': 94560,
#  'wertheim': 94557,
#  'were\\whipsawed': 94554,
#  'zig': 95759,
#  'were\\under': 94552,
#  'were\\struggling': 94551,
#  'were\\pioneered': 94547,
#  'were\\not': 94546,
#  'were\\investigating': 94542,
#  'were\\expected': 94539,
#  'were\\evaporating': 94538,
#  'were\\contemplating': 94537,
#  'were\\color-coded': 94536,
#  'were\\attempting': 94535,
#  'were\\arab': 94534,
#  'were\\among': 94533,
#  'wenzhong': 94532,
#  'wends': 94530,
#  'wend': 94528,
#  'welter': 94526,
#  'welshmen': 94524,
#  'welshmans': 94523,
#  'wellness': 94520,
#  'wellington-based': 94519,
#  'welles': 94518,
#  'well-worked': 94514,
#  'well-taken': 94513,
#  'well-suited': 94512,
#  'well-reported': 94508,
#  'well-publicized': 94506,
#  'well-preserved': 94505,
#  'well-oiled': 94497,
#  'well-meaning': 94495,
#  'well-mannered': 94493,
#  'well-furnished': 94488,
#  'well-drilled': 94485,
#  'well-beaten': 94479,
#  'well-balanced': 94478,
#  'well-adjusted': 94476,
#  'well-above': 94475,
#  'welds': 94471,
#  'weirdly-named': 94465,
#  'weinreich': 94463,
#  'weinberger': 94462,
#  'weills': 94459,
#  'weiler': 94458,
#  'weil': 94457,
#  'weighting': 94456,
#  'weigh-in': 94452,
#  'weidner': 94451,
#  'weiberg': 94450,
#  'weepu': 94445,
#  'weeks\\after': 94442,
#  'weekin': 94439,
#  'week\\with': 94434,
#  'week-over-week': 94431,
#  'wednesdayone': 94426,
#  'wednesday\\warned': 94424,
#  'wednesday\\introduced': 94419,
#  'wednesday\\enlisted': 94417,
#  'wednesday\\as': 94413,
#  'wedgies': 94407,
#  'wedged': 94405,
#  'wedge-shaped': 94404,
#  'wecker': 94399,
#  'websites\\\\i': 94397,
#  'webs': 94395,
#  'webroot': 94394,
#  'webpreneurs': 94393,
#  'webloggers': 94391,
#  'weblinks': 94390,
#  'webhead': 94387,
#  'webfetch': 94386,
#  'webentry': 94385,
#  'webcasting': 94382,
#  'webbers': 94381,
#  'webb\\\\this': 94380,
#  'web\\start-up': 94378,
#  'web\\site': 94377,
#  'web\\search': 94376,
#  'web-transaction': 94372,
#  'web-surfing': 94371,
#  'web-savvy': 94368,
#  'web-page': 94366,
#  'web-hosted': 94365,
#  'web-facing': 94364,
#  'web-app': 94358,
#  'weather-weary': 94353,
#  'weather-ravaged': 94352,
#  'weather-affected': 94346,
#  'weasels': 94345,
#  'wearside': 94343,
#  'wearers': 94342,
#  'wearer': 94341,
#  'wear-shattered': 94340,
#  'weaponsprogram': 94339,
#  'weapons-smuggling': 94337,
#  'weaponization': 94333,
#  'weaker-than-forecast': 94330,
#  'weak\\u': 94328,
#  'weak\\machinery': 94325,
#  'we\\shared': 94322,
#  'we&lt': 94320,
#  'wd-40': 94318,
#  'wcg': 94316,
#  'wcco': 94315,
#  'wcb': 94314,
#  'wbur': 94313,
#  'wbf': 94312,
#  'wbca': 94311,
#  'way\\most': 94301,
#  'waviness': 94296,
#  'wavelength': 94295,
#  'wave\\rat': 94294,
#  'watterson': 94292,
#  'watersheds': 94287,
#  'waterproofing': 94286,
#  'watermelons': 94283,
#  'watermarks': 94282,
#  'waterfield': 94278,
#  'waterborne': 94276,
#  'water\\treatment': 94275,
#  'water\\melons': 94274,
#  'water-skier': 94272,
#  'water-rate': 94271,
#  'water-purification': 94270,
#  'water-methane': 94269,
#  'water-bomber': 94264,
#  'watchdog\\friday': 94262,
#  'watchdog\\body': 94261,
#  'watchdog\\arrived': 94260,
#  'watanabe': 94259,
#  'washtenaw': 94251,
#  'washingtonus': 94249,
#  'washingtonfcc': 94247,
#  'washingtonamerican': 94245,
#  'washingtona': 94244,
#  'washington/san': 94239,
#  'washington/london': 94238,
#  'washington/boston': 94236,
#  'washington-oregon': 94235,
#  'washington-nextwave': 94233,
#  'washington--two': 94226,
#  'washington--north': 94225,
#  'washington--cynics': 94222,
#  'washington--a': 94221,
#  'wash-out': 94218,
#  'wasdiverted': 94215,
#  'wasdin': 94214,
#  'wasatch': 94213,
#  'was_particularly': 94212,
#  'was\\worth': 94210,
#  'was\\unexpectedly': 94208,
#  'was\\thinking': 94207,
#  'was\\stopped': 94205,
#  'was\\passing': 94202,
#  'was\\particularly': 94201,
#  'was\\optimistic': 94200,
#  'was\\negotiating': 94199,
#  'was\\linked': 94195,
#  'was\\launched': 94194,
#  'was\\kidnapped': 94192,
#  'was\\in': 94191,
#  'was\\expected': 94188,
#  'was\\accompanied': 94182,
#  'warspammer': 94178,
#  'warshak': 94177,
#  'warricks': 94175,
#  'warranting': 94172,
#  'warping': 94171,
#  'warning\\doctors': 94169,
#  'warning\\\\as': 94168,
#  'warner/comcast': 94165,
#  'warned\\people': 94161,
#  'warned\\hikers': 94158,
#  'warming-csiro': 94156,
#  'warmin': 94155,
#  'warmhearted': 94154,
#  'warm\\home': 94153,
#  'warlord\\to': 94151,
#  'warlanes': 94148,
#  'waries': 94146,
#  'warhorse': 94145,
#  'wargames': 94142,
#  'warfighter': 94141,
#  'warfield': 94140,
#  'warez': 94138,
#  'warehouse-style': 94137,
#  'wareham': 94135,
#  'wardrive': 94133,
#  'warders': 94132,
#  'wardens': 94131,
#  'ward-based': 94129,
#  'warchest': 94128,
#  'waratteiy-oh': 94126,
#  'war\\over': 94124,
#  'war\\on': 94123,
#  'war\\and': 94121,
#  'war-style': 94119,
#  'war-lord': 94115,
#  'war--and': 94112,
#  'wanted\\islamic': 94109,
#  'wanted\\elections': 94108,
#  'wan-gah': 94100,
#  'wallenberg': 94087,
#  'wallaces': 94086,
#  'walkthrough': 94083,
#  'walkie-talkie-like': 94081,
#  'walkie-': 94080,
#  'walkersville': 94079,
#  'walkerinformation': 94078,
#  'walk-through': 94075,
#  'walk-fest': 94074,
#  'waless': 94072,
#  'waldorf-astoria': 94071,
#  'wal-martisation': 94068,
#  'wal-mart\\rises': 94067,
#  'waitz': 94062,
#  'wait\\decades': 94056,
#  'waisglass': 94051,
#  'wais': 94050,
#  'wahab': 94047,
#  'wages\\and': 94044,
#  'waffling': 94038,
#  'wadia': 94036,
#  'wada-affiliated': 94034,
#  'wackiest': 94033,
#  'wacked': 94031,
#  'wabasha': 94027,
#  'wabash': 94026,
#  'w32/zafi': 94022,
#  'w1100z': 94018,
#  'w/': 94017,
#  'w-lan': 94016,
#  'w-l': 94015,
#  'vye': 94013,
#  'vyacheslav': 94011,
#  'vvv': 94009,
#  'vulnerabilty': 94005,
#  'vug': 94003,
#  'vtg': 94002,
#  'vsamarra': 93999,
#  'yanukovychdesires': 95441,
#  'vsam': 93998,
#  'vrtx': 93997,
#  'vremya': 93995,
#  'vreij': 93994,
#  'vra': 93993,
#  'voyagers': 93987,
#  'voxilla': 93986,
#  'vowels': 93982,
#  'vowel-centered': 93981,
#  'vowed\\to': 93980,
#  'voting-equipment': 93978,
#  'votes\\in': 93977,
#  'voter-rights': 93975,
#  'voter-education': 93974,
#  'vote\\\\': 93968,
#  'vote-getter': 93967,
#  'vostok': 93962,
#  'vormetric': 93960,
#  'voraciously': 93959,
#  'vont': 93958,
#  'vonage-only': 93956,
#  'volos': 93951,
#  'volgenau': 93948,
#  'volcker': 93945,
#  'voke': 93942,
#  'voip-friendly': 93939,
#  'voicemails': 93932,
#  'voice-over-broadband': 93929,
#  'voice-enabling': 93927,
#  'voice--in': 93923,
#  'vohor': 93922,
#  'vogel': 93919,
#  'vodichkova': 93917,
#  'voda': 93913,
#  'vod': 93912,
#  'voce': 93911,
#  'voca': 93907,
#  'vns': 93905,
#  'will\\succeed': 94868,
#  'vlt': 93901,
#  'vlbi': 93899,
#  'vladimir\\guerrero': 93896,
#  'vj': 93891,
#  'vivar': 93884,
#  'viv': 93881,
#  'vitiate': 93876,
#  'visualizations': 93870,
#  'visual\\attraction': 93869,
#  'visited\\brazil': 93865,
#  'vishwa': 93860,
#  'virus-scan': 93854,
#  'virtuous': 93849,
#  'virtul': 93847,
#  'virtualised': 93845,
#  'virtual-library': 93842,
#  'viropharma': 93841,
#  'virologists': 93840,
#  'virgnia': 93837,
#  'viper': 93827,
#  'violentattacks': 93825,
#  'violencia': 93824,
#  'violence-troubled': 93820,
#  'violations\\of': 93817,
#  'vine': 93813,
#  'vindigo': 93812,
#  'vima': 93809,
#  'ville': 93805,
#  'villainize': 93803,
#  'voix': 93941,
#  'villager': 93802,
#  'village\\known': 93801,
#  'village\\and': 93800,
#  'vilamoura': 93798,
#  'viktor\\yushchenko': 93796,
#  'vik': 93794,
#  'vijays': 93793,
#  'vijaykumar': 93792,
#  'vijaykanth': 93791,
#  'vijayan': 93790,
#  'vijay-els': 93789,
#  'vij': 93788,
#  'vih': 93785,
#  'vigour': 93784,
#  'vignettes': 93783,
#  'vignal': 93782,
#  'viewership': 93776,
#  'view\\mirror': 93774,
#  'view-stocks-us': 93771,
#  'vietnamese-australian': 93769,
#  'vietnam\\service': 93767,
#  'viet-ville': 93765,
#  'world\\today': 95194,
#  'viesturs': 93763,
#  'viennna': 93760,
#  'viegas': 93756,
#  'videoconference': 93751,
#  'video\\games': 93748,
#  'video\\display': 93746,
#  'video\\camera': 93745,
#  'video-to-go': 93744,
#  'video-store': 93742,
#  'video-rental': 93741,
#  'video-clip': 93737,
#  'victuals': 93734,
#  'victory\\against': 93733,
#  'victorine': 93730,
#  'victorians': 93729,
#  'voil': 93937,
#  'victims\\\\ask': 93727,
#  'vicksburg': 93723,
#  'vickrey': 93722,
#  'vican': 93714,
#  'viatcheslav': 93712,
#  'viaductof': 93708,
#  'via\\the': 93707,
#  'via\\high-speed': 93705,
#  'vhp': 93704,
#  'vevey': 93700,
#  'vetoing': 93697,
#  'veteran\\hugh': 93693,
#  'vested': 93690,
#  'vesta': 93689,
#  'vesicles': 93688,
#  'verwaltung': 93686,
#  'vertu': 93684,
#  'versus\\philadelphia': 93682,
#  'verstatile': 93681,
#  'versioning': 93680,
#  'version\\of': 93679,
#  'versamark': 93677,
#  'versace': 93676,
#  'verpakovskis': 93674,
#  'vernacular': 93672,
#  'vern': 93671,
#  'vermontdemocrats': 93670,
#  'vermiculite': 93669,
#  'vermeer': 93668,
#  'verisignlost': 93662,
#  'verged': 93659,
#  'verdon': 93658,
#  'verbiage': 93655,
#  'verarbeitet': 93652,
#  'verantwortlich': 93651,
#  'veracruz': 93649,
#  'ver': 93648,
#  'ventureone': 93646,
#  'ventilation-systems': 93643,
#  'venti\\vanilla': 93642,
#  'venomous': 93640,
#  'vengsarkar': 93638,
#  'wicket-keeper/batsman': 94772,
#  'vengeful': 93637,
#  'venezuelanspray': 93635,
#  'venezuela\\have': 93633,
#  'vendor-neutral': 93627,
#  'vendee': 93626,
#  'ven': 93625,
#  'velush': 93624,
#  'velocities': 93623,
#  'vehicle-repair': 93618,
#  'vehicle-emissions': 93617,
#  'veggies': 93615,
#  'vegetarians': 93613,
#  'vegetarian-safe': 93612,
#  'vegasbea': 93610,
#  'vegas\\hotels': 93609,
#  'veerapan': 93606,
#  'veena': 93605,
#  'vectors': 93604,
#  'vecernje': 93603,
#  've-part': 93600,
#  'vdmn': 93598,
#  'vcx': 93595,
#  'vcrs\\have': 93593,
#  'vcr/dvd': 93592,
#  'vcr-like': 93591,
#  'vc7': 93589,
#  'vb': 93588,
#  'vazu': 93587,
#  'vaxgen': 93586,
#  'vaughan-inspired': 93585,
#  'vat': 93583,
#  'vasillias': 93577,
#  'vase': 93574,
#  'varying\\prices': 93573,
#  'willy': 94884,
#  'varsho': 93572,
#  'varley': 93570,
#  'variable-rate': 93566,
#  'variability': 93564,
#  'vaph': 93558,
#  'vanjoki': 93555,
#  'vanities': 93554,
#  'vanes': 93553,
#  'vandy': 93552,
#  'vandal': 93549,
#  'vanco': 93548,
#  'vampire-style': 93546,
#  'valujet': 93542,
#  'value-minded': 93541,
#  'value-for-money': 93540,
#  'value-focused': 93539,
#  'valuation\\is': 93538,
#  'valuable\\player': 93536,
#  'valleyski': 93534,
#  'valley-based': 93532,
#  'valles': 93531,
#  'validly': 93530,
#  'validating': 93528,
#  'validated': 93527,
#  'valderamma': 93521,
#  'vakulenko': 93520,
#  'vainglorious': 93518,
#  'vagrants': 93516,
#  'vagit': 93514,
#  'vaccine\\manufacturer': 93511,
#  'vaccine-manufacturing': 93510,
#  'vacationed': 93506,
#  'v6': 93499,
#  'v2i': 93496,
#  'v1': 93494,
#  'v-i-c-t-o-r-y': 93493,
#  'uzlovaya': 93491,
#  'uves': 93485,
#  'uttr': 93481,
#  'utterances': 93480,
#  'utopianism': 93477,
#  'utilities\\commission': 93472,
#  'utilising': 93470,
#  'utilises': 93469,
#  'utilise': 93467,
#  'util': 93466,
#  'uterus': 93464,
#  'usurps': 93458,
#  'usu': 93456,
#  'ustody': 93454,
#  'ustinov': 93453,
#  'ussr': 93452,
#  'ussid': 93451,
#  'uss\\$4': 93450,
#  'usl': 93447,
#  'using\\chemicals': 93443,
#  ...}

# %%
vocab.get_itos()
# Out:
# ['<unk>',
#  '<sos>',
#  '<eos>',
#  '.',
#  'the',
#  ',',
#  'to',
#  'a',
#  'of',
#  'in',
#  'and',
#  's',
#  'elkabetz',
#  'on',
#  'for',
#  '#39',
#  '(',
#  ')',
#  '-',
#  "'",
#  'that',
#  'with',
#  'as',
#  'at',
#  'is',
#  'its',
#  'new',
#  'by',
#  'it',
#  'said',
#  'reuters',
#  'has',
#  'from',
#  'an',
#  'ap',
#  'his',
#  'will',
#  'after',
#  'was',
#  'us',
#  'be',
#  'over',
#  'have',
#  'their',
#  '&lt',
#  'are',
#  'up',
#  'quot',
#  'but',
#  'more',
#  'first',
#  'two',
#  'he',
#  'world',
#  'u',
#  'this',
#  '--',
#  'company',
#  'monday',
#  'wednesday',
#  'tuesday',
#  'oil',
#  'out',
#  'thursday',
#  'one',
#  'not',
#  'against',
#  'inc',
#  'friday',
#  'into',
#  'they',
#  'about',
#  'last',
#  'iraq',
#  'year',
#  'than',
#  'york',
#  'yesterday',
#  'who',
#  'president',
#  'microsoft',
#  'no',
#  'were',
#  '?',
#  'been',
#  'million',
#  't',
#  'says',
#  'week',
#  'had',
#  'corp',
#  'united',
#  'game',
#  'when',
#  'sunday',
#  'prices',
#  'could',
#  'three',
#  'would',
#  'today',
#  'years',
#  'group',
#  'security',
#  'government',
#  'time',
#  'people',
#  'which',
#  'may',
#  'afp',
#  'percent',
#  'software',
#  '1',
#  'win',
#  'off',
#  'team',
#  'next',
#  'back',
#  'saturday',
#  'night',
#  'or',
#  'china',
#  'internet',
#  'season',
#  '2',
#  'deal',
#  'can',
#  'some',
#  'sales',
#  'minister',
#  'market',
#  'second',
#  'bush',
#  'state',
#  'all',
#  'top',
#  'day',
#  'business',
#  'announced',
#  'down',
#  'news',
#  'n',
#  'international',
#  'billion',
#  '2004',
#  'former',
#  'killed',
#  'most',
#  'washington',
#  'record',
#  'victory',
#  'officials',
#  'report',
#  'open',
#  'city',
#  'stocks',
#  'end',
#  'profit',
#  'plans',
#  'court',
#  'if',
#  'service',
#  'other',
#  'states',
#  'home',
#  'four',
#  '000',
#  '/b&gt',
#  'b&gt',
#  'you',
#  'set',
#  'before',
#  'european',
#  'chief',
#  'lead',
#  'technology',
#  'com',
#  'talks',
#  'cup',
#  'american',
#  'league',
#  'just',
#  'search',
#  'computer',
#  'space',
#  'online',
#  'country',
#  'what',
#  'national',
#  'now',
#  'reported',
#  'shares',
#  'british',
#  'take',
#  'bank',
#  'third',
#  'won',
#  'japan',
#  'federal',
#  'red',
#  'india',
#  'major',
#  'police',
#  'prime',
#  'network',
#  'least',
#  'google',
#  'make',
#  '10',
#  'ibm',
#  'another',
#  'research',
#  'iraqi',
#  'according',
#  'music',
#  'south',
#  'made',
#  'leader',
#  'companies',
#  'help',
#  'final',
#  '3',
#  'co',
#  'maker',
#  'during',
#  'games',
#  'get',
#  'while',
#  'web',
#  'month',
#  'bid',
#  'coach',
#  'san',
#  'there',
#  'between',
#  'hit',
#  'plan',
#  'say',
#  'series',
#  'still',
#  'london',
#  'high',
#  'largest',
#  'baghdad',
#  'expected',
#  'industry',
#  'big',
#  'election',
#  'mobile',
#  'them',
#  'giant',
#  'five',
#  '5',
#  'way',
#  'growth',
#  'since',
#  'through',
#  'investor',
#  'services',
#  '//www',
#  'her',
#  '/a&gt',
#  'early',
#  'href=http',
#  '4',
#  'quarter',
#  'sports',
#  'wireless',
#  'system',
#  'data',
#  'north',
#  'under',
#  'trade',
#  'war',
#  'australia',
#  'earnings',
#  'dollar',
#  'military',
#  'buy',
#  'cut',
#  'gold',
#  'being',
#  'union',
#  'nuclear',
#  'higher',
#  'john',
#  'i',
#  'him',
#  'move',
#  'phone',
#  'un',
#  'only',
#  'players',
#  'test',
#  'start',
#  'left',
#  'amp',
#  'official',
#  'stock',
#  'apple',
#  'loss',
#  'palestinian',
#  'agreed',
#  'months',
#  'sox',
#  'days',
#  'because',
#  'so',
#  '7',
#  'attack',
#  'many',
#  'latest',
#  'aspx',
#  'com/fullquote',
#  'target=/stocks/quickinfo/fullquote&gt',
#  'troops',
#  'oracle',
#  'olympic',
#  'windows',
#  'england',
#  'global',
#  'like',
#  'intel',
#  'russia',
#  'firm',
#  'israeli',
#  'gaza',
#  'air',
#  'rose',
#  'again',
#  'found',
#  'executive',
#  'press',
#  'jobs',
#  'west',
#  'even',
#  'users',
#  'general',
#  'including',
#  'man',
#  'play',
#  'reports',
#  'rise',
#  'iran',
#  'update',
#  'football',
#  'price',
#  'boston',
#  'released',
#  'despite',
#  'points',
#  'economy',
#  'drug',
#  'ago',
#  'ahead',
#  'athens',
#  'forces',
#  'past',
#  'pay',
#  'near',
#  'biggest',
#  'how',
#  'europe',
#  'part',
#  'investors',
#  'peace',
#  'release',
#  'go',
#  'canadian',
#  'economic',
#  'six',
#  'head',
#  'peoplesoft',
#  'car',
#  'russian',
#  'o',
#  'key',
#  'offer',
#  'street',
#  'beat',
#  'work',
#  'your',
#  'free',
#  'pakistan',
#  'held',
#  'case',
#  'use',
#  'eu',
#  'public',
#  'strong',
#  'uk',
#  '2005',
#  'power',
#  'much',
#  'where',
#  'title',
#  'run',
#  'should',
#  'weeks',
#  '6',
#  'foreign',
#  'nearly',
#  'video',
#  'presidential',
#  'workers',
#  'bomb',
#  'wins',
#  'america',
#  'pc',
#  'attacks',
#  'tokyo',
#  'nation',
#  'israel',
#  'systems',
#  'nations',
#  'share',
#  'support',
#  'financial',
#  'close',
#  'nasa',
#  'sun',
#  'championship',
#  'contract',
#  'media',
#  'korea',
#  'launch',
#  'agency',
#  'do',
#  'australian',
#  'st',
#  'round',
#  'fall',
#  'kerry',
#  'leaders',
#  'put',
#  'wall',
#  'french',
#  'men',
#  'linux',
#  'around',
#  'house',
#  'number',
#  'francisco',
#  'fell',
#  'called',
#  '8',
#  'long',
#  'took',
#  'player',
#  'face',
#  'digital',
#  'death',
#  'lower',
#  'september',
#  'october',
#  '20',
#  'crude',
#  'scientists',
#  'net',
#  'used',
#  'also',
#  'any',
#  'following',
#  'florida',
#  'killing',
#  'chicago',
#  'job',
#  'good',
#  'darfur',
#  'return',
#  'leading',
#  'arafat',
#  '#36',
#  'late',
#  'program',
#  'rival',
#  'seven',
#  '11',
#  'version',
#  'here',
#  'army',
#  'capital',
#  'charges',
#  'right',
#  'keep',
#  'life',
#  'consumer',
#  'agreement',
#  'quote',
#  'commission',
#  'demand',
#  'both',
#  'campaign',
#  'future',
#  'bill',
#  'japanese',
#  'trial',
#  'race',
#  'france',
#  'center',
#  'vote',
#  'hurricane',
#  'yankees',
#  'party',
#  'site',
#  'n&lt',
#  'best',
#  'strike',
#  'give',
#  'region',
#  'products',
#  'we',
#  'dead',
#  'women',
#  'britain',
#  'half',
#  'per',
#  'board',
#  'might',
#  '12',
#  'customers',
#  'show',
#  'several',
#  'away',
#  'battle',
#  'results',
#  'conference',
#  'study',
#  'decision',
#  'defense',
#  'fourth',
#  'manager',
#  'november',
#  'northern',
#  'meeting',
#  'costs',
#  'without',
#  'militants',
#  'chip',
#  'gets',
#  'office',
#  'southern',
#  'line',
#  'sony',
#  'takes',
#  'political',
#  'sudan',
#  'management',
#  'champions',
#  'elections',
#  'school',
#  'energy',
#  'little',
#  'recent',
#  'champion',
#  'cuts',
#  'judge',
#  'due',
#  'baseball',
#  'fight',
#  'central',
#  'profile',
#  'california',
#  'such',
#  'hopes',
#  '9',
#  'sell',
#  'fans',
#  'making',
#  'hostage',
#  'canada',
#  'force',
#  'she',
#  'told',
#  '30',
#  'claims',
#  'health',
#  'quarterly',
#  'los',
#  'field',
#  '\\$1',
#  'department',
#  'michael',
#  'straight',
#  'whether',
#  'place',
#  'well',
#  'interest',
#  'giants',
#  'scored',
#  'third-quarter',
#  'likely',
#  'increase',
#  'grand',
#  'using',
#  'ceo',
#  '15',
#  'real',
#  'm',
#  'across',
#  'university',
#  'own',
#  'running',
#  'amid',
#  'mark',
#  'become',
#  'lost',
#  'saying',
#  'club',
#  'tv',
#  'winning',
#  'taking',
#  'angeles',
#  'launched',
#  'history',
#  'rates',
#  'look',
#  'times',
#  'source',
#  'star',
#  'unit',
#  'tax',
#  'violence',
#  'weekend',
#  'match',
#  'texas',
#  'chinese',
#  '0',
#  'hits',
#  'chairman',
#  'east',
#  'stores',
#  'among',
#  'houston',
#  'eight',
#  'germany',
#  'server',
#  'trading',
#  'too',
#  'oct',
#  'small',
#  'better',
#  'rebels',
#  'shot',
#  '18',
#  'accused',
#  'control',
#  'williams',
#  'phones',
#  'rate',
#  'behind',
#  'action',
#  'change',
#  'desktop',
#  'seen',
#  'possible',
#  'come',
#  'makes',
#  'boost',
#  'profits',
#  'information',
#  'ipod',
#  'aid',
#  'injured',
#  'meet',
#  'led',
#  'hold',
#  'afghanistan',
#  'going',
#  'few',
#  'soldiers',
#  'yahoo',
#  'drop',
#  'morning',
#  'august',
#  'operating',
#  'calls',
#  'senior',
#  'tech',
#  'see',
#  'communications',
#  'did',
#  'reach',
#  'german',
#  'low',
#  'revenue',
#  'warned',
#  'call',
#  'almost',
#  'bankruptcy',
#  'thousands',
#  'exchange',
#  'rally',
#  'law',
#  'nov',
#  'airlines',
#  'paris',
#  '25',
#  '14',
#  'e-mail',
#  'takeover',
#  'radio',
#  'white',
#  'africa',
#  'access',
#  'those',
#  'reserve',
#  'showed',
#  'indian',
#  'stadium',
#  'cash',
#  'medal',
#  'posted',
#  'cell',
#  'gas',
#  'less',
#  'tour',
#  'afghan',
#  'yet',
#  'barrel',
#  'ready',
#  'david',
#  'forecast',
#  'production',
#  'wants',
#  'coast',
#  'fire',
#  'old',
#  'markets',
#  'got',
#  'offering',
#  'step',
#  'spain',
#  'same',
#  'engine',
#  'nfl',
#  '13',
#  'division',
#  'jones',
#  'signed',
#  'television',
#  'toronto',
#  'outlook',
#  'euro',
#  'opposition',
#  'begin',
#  'must',
#  'sale',
#  'soon',
#  'stake',
#  'find',
#  'helped',
#  '16',
#  'secretary',
#  '100',
#  'association',
#  'al',
#  'olympics',
#  'probe',
#  'began',
#  'money',
#  'blair',
#  'earlier',
#  'came',
#  'concerns',
#  'human',
#  'ltd',
#  'sign',
#  '!',
#  'fuel',
#  'stop',
#  'americans',
#  'sept',
#  'store',
#  'fund',
#  'corporate',
#  'insurance',
#  'product',
#  'gains',
#  'networks',
#  'countries',
#  'efforts',
#  'local',
#  'target',
#  'threat',
#  'opening',
#  '17',
#  'green',
#  'died',
#  'legal',
#  'members',
#  'airline',
#  'african',
#  'ended',
#  'administration',
#  'already',
#  'station',
#  'cost',
#  'arrested',
#  'council',
#  'analysts',
#  'investment',
#  'need',
#  'nine',
#  'trying',
#  'within',
#  'list',
#  'competition',
#  'spending',
#  'visit',
#  'teams',
#  'continue',
#  'madrid',
#  'arsenal',
#  'great',
#  'food',
#  'rules',
#  'ever',
#  'others',
#  'airways',
#  'pm',
#  'computers',
#  'growing',
#  'terror',
#  'charged',
#  'family',
#  'personal',
#  'supply',
#  'don',
#  'hours',
#  'outside',
#  'looking',
#  'until',
#  'fighting',
#  'western',
#  'far',
#  'retail',
#  'george',
#  'heart',
#  'miami',
#  'nba',
#  'flight',
#  'authorities',
#  'enough',
#  'beijing',
#  'gave',
#  'starting',
#  'offers',
#  'once',
#  'sharon',
#  'dell',
#  'performance',
#  'black',
#  'holiday',
#  'manchester',
#  'pressure',
#  'finally',
#  'paul',
#  'toward',
#  'effort',
#  'rights',
#  'yards',
#  'reached',
#  'ruling',
#  'coming',
#  'consumers',
#  'weapons',
#  'blue',
#  'bay',
#  'executives',
#  '#151',
#  'ban',
#  'development',
#  'fears',
#  'crisis',
#  'each',
#  'italian',
#  'children',
#  'sees',
#  'suicide',
#  'bowl',
#  'seattle',
#  'quarterback',
#  'taken',
#  'charge',
#  'devices',
#  'drive',
#  'retailer',
#  'getting',
#  'aimed',
#  'cisco',
#  'popular',
#  '19',
#  'failed',
#  'survey',
#  'then',
#  'yukos',
#  'operations',
#  'labor',
#  'push',
#  'shows',
#  'problems',
#  'kill',
#  'blast',
#  'continued',
#  'd',
#  'researchers',
#  'injury',
#  'ivan',
#  'main',
#  'college',
#  'electronics',
#  'further',
#  'basketball',
#  'hope',
#  'yasser',
#  'rebel',
#  'storm',
#  'soccer',
#  'want',
#  'rising',
#  'davis',
#  'policy',
#  'rivals',
#  'filed',
#  'focus',
#  'missing',
#  'palestinians',
#  'calif',
#  'fraud',
#  'kills',
#  'hard',
#  'powerful',
#  'private',
#  'moscow',
#  'raised',
#  'working',
#  'suspected',
#  'defeat',
#  'leave',
#  'challenge',
#  'faces',
#  'firms',
#  'turn',
#  'warning',
#  'chips',
#  'side',
#  'signs',
#  'merger',
#  'above',
#  'asian',
#  'selling',
#  'winter',
#  'short',
#  'atlanta',
#  'name',
#  'mission',
#  'p',
#  'designed',
#  'career',
#  'annual',
#  'park',
#  'point',
#  '2006',
#  'goal',
#  'investigation',
#  'try',
#  'risk',
#  'issue',
#  'dollars',
#  'staff',
#  'went',
#  'named',
#  'allow',
#  'chance',
#  'satellite',
#  'never',
#  'planned',
#  '50',
#  'delta',
#  'debt',
#  'fresh',
#  'issues',
#  'large',
#  'tony',
#  'lawsuit',
#  'sold',
#  'area',
#  'asia',
#  'businesses',
#  'c',
#  'fired',
#  'full',
#  'storage',
#  'provide',
#  'expectations',
#  '24',
#  'xp',
#  'nokia',
#  'town',
#  '21',
#  ...]

# %%
from torchtext.vocab import vocab
from collections import Counter, OrderedDict
counter = Counter(["a", "a", "b", "b", "b"])
sorted_by_freq_tuples = sorted(counter.items(), key=lambda x: x[1], reverse=True)
print(counter)
print(sorted_by_freq_tuples)
# Out:
# Counter({'b': 3, 'a': 2})
# [('b', 3), ('a', 2)]

# %%
ordered_dict = OrderedDict(sorted_by_freq_tuples)
print(ordered_dict)
# Out:
# OrderedDict([('b', 3), ('a', 2)])

# %%
v1 = vocab(ordered_dict)
print(v1['a']) #prints 1
print(v1['out of vocab']) #raise RuntimeError since default index is not set
# Out:
# 1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-89e241aec453> in <module>()
#       1 v1 = vocab(ordered_dict)
#       2 print(v1['a']) #prints 1
# ----> 3 print(v1['out of vocab']) #raise RuntimeError since default index is not set
#
# /usr/local/lib/python3.7/dist-packages/torchtext/vocab.py in __getitem__(self, token)
#      82             The index corresponding to the associated token.
#      83         """
# ---> 84         return self.vocab[token]
#      85
#      86     @torch.jit.export
#
# RuntimeError: Token out of vocab not found and default index is not set

# %%
tokens = ['e', 'd', 'c', 'b', 'a']
v2 = vocab(OrderedDict([(token, 1) for token in tokens]))
#adding <unk> token and default index
unk_token = '<unk>'
default_index = -1
if unk_token not in v2: v2.insert_token(unk_token, 0)
v2.set_default_index(default_index)
print(v2['<unk>']) #prints 0
print(v2['out of vocab']) #prints -1
#make default index same as index of unk_token
v2.set_default_index(v2[unk_token])
v2['out of vocab'] is v2[unk_token] #prints True
# Out:
# 0
# -1
# True
